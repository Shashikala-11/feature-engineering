# %%
import pickle

# %%
import numpy as np

# %%
ohe_sex=pickle.load(open('dataset\ohe_sex.pkl','rb'))
ohe_embarked=pickle.load(open('dataset\ohe_embarked.pkl','rb'))
clf=pickle.load(open('dataset\clf.pkl','rb'))
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator OneHotEncoder from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Assume user input
test_input=np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex=ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1 stored elements and shape (1, 2)>

# %%
test_input_embarked=ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1 stored elements and shape (1, 3)>

# %%
test_input_age=test_input[:,2].reshape(1,1)

# %%
test_input_sex = ohe_sex.transform(test_input[:, [1]]).toarray()
test_input_embarked = ohe_embarked.transform(test_input[:, [5]]).toarray()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_transformed=np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)
