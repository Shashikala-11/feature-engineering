# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %% [markdown]
# ## 1. One hot Encoding using pandas

# %%
df.nunique()
# Out:
# brand             32
# km_driven        921
# fuel               4
# owner              5
# selling_price    677
# dtype: int64

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %%
df2=(pd.get_dummies(df,columns=['fuel','owner'],dtype=int))
df2
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000         0            1         0
# 1       Skoda     120000         370000         0            1         0
# 2       Honda     140000         158000         0            0         0
# 3     Hyundai     127000         225000         0            1         0
# 4      Maruti     120000         130000         0            0         0
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000         0            0         0
# 8124  Hyundai     119000         135000         0            1         0
# 8125   Maruti     120000         382000         0            1         0
# 8126     Tata      25000         290000         0            1         0
# 8127     Tata      25000         290000         0            1         0
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# ## 2. k-1 OneHotencoding

# %%
df2=(pd.get_dummies(df,columns=['fuel','owner'],dtype=int,drop_first=True))
df2
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# #### Problem with pandas OneHotEncoding:
#
# It doesn't remeber the order of encoding given to columns in specific. It randomly assigns encoded value to columns so it becomes difficult to identify the columns with those encoded values.
#
# Due to this , we use sklearn OneHotEncoding .

# %% [markdown]
# ## 3. OneHotEncoding using sklearn

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,0:4],df.iloc[:,:-1],test_size=0.2,random_state=42)

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
X_train
# Out:
#          brand  km_driven    fuel                 owner
# 6518      Tata       2560  Petrol           First Owner
# 6144     Honda      80000  Petrol          Second Owner
# 6381   Hyundai     150000  Diesel  Fourth & Above Owner
# 438     Maruti     120000  Diesel          Second Owner
# 5939    Maruti      25000  Petrol           First Owner
# ...        ...        ...     ...                   ...
# 5226  Mahindra     120000  Diesel           First Owner
# 5390    Maruti      80000  Diesel          Second Owner
# 860    Hyundai      35000  Petrol           First Owner
# 7603    Maruti      27000  Diesel           First Owner
# 7270    Maruti      70000  Petrol          Second Owner
#
# [6502 rows x 4 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(drop='first')

# %%
X_train_new=ohe.fit_transform(X_train[['fuel','owner']])
X_test_new=ohe.transform(X_test[['fuel','owner']])

# %%
X_train_new.shape
# Out:
# (6502, 7)

# %%
np.hstack((X_train[['brand','km_driven']].values,X_train_new.toarray())).shape
# Out:
# (6502, 9)

# %% [markdown]
# ### 4. OneHotEncoding with Top Categories

# %%
counts=df['brand'].value_counts()
counts
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].nunique()
# Out:
# 32

# %%
threshold=100

# %%
repl=counts[counts<=threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl,'unknown')).sample(10)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 2515  False      False  False  False    False     False    True    False
# 7711  False      False  False  False    False     False   False    False
# 4017  False      False  False  False    False     False    True    False
# 2650  False      False  False  False    False     False   False    False
# 1813  False       True  False  False    False     False   False    False
# 863   False      False  False  False     True     False   False    False
# 5527  False      False  False  False    False     False    True    False
# 1616  False      False  False  False    False     False   False    False
# 5707  False      False  False  False    False     False   False    False
# 7433  False      False  False  False    False     False    True    False
#
#       Skoda   Tata  Toyota  Volkswagen  unknown
# 2515  False  False   False       False    False
# 7711  False  False   False       False     True
# ...
